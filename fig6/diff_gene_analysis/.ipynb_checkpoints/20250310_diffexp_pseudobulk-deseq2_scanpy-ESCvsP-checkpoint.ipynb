# %% [markdown]
# # Load packages

# %% [markdown]
# Read in all necessary packages:

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc
import numpy as np
import decoupler as dc
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# Import DESeq2
from pydeseq2.dds import DeseqDataSet, DefaultInference
from pydeseq2.ds import DeseqStats

# %%
import decoupler as dc

# %%
sc.set_figure_params(dpi = 80)
sns.set_style("white")
sns.set_context("talk")
sns.set_style("ticks")

# %% [markdown]
# # Load the dataset

# %% [markdown]
# ## load adata file and define groups for differential expression

# %%
adata = sc.read_h5ad('../../../tchic_local/fig6_build/legacy/data/20230704_adata_all.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 38117 × 27384
#     obs: 'batch', 'day', 'replicates', 'mark', 'day_rep', 'dataset', 'hour', 'celltype', 'celltype_general', 'lineage', 'lin_day', 'percent_mito', 'n_counts', 'n_counts_proteincoding', 'n_genes', 'S_score', 'G2M_score', 'phase', 'enrichment', 'coverage', 'QC', 'pseudotime', 'pseudotime2'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'gene', 'gene_biotype', 'gene_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'QC_colors', 'batch_colors', 'celltype_colors', 'celltype_general_colors', 'dataset_colors', 'day_colors', 'hour_colors', 'hvg', 'leiden', 'leiden_colors', 'lin_day_colors', 'lineage_colors', 'log1p', 'mark_colors', 'neighbors', 'old_celltype_colors', 'old_leiden_general_colors', 'old_leiden_merge_colors', 'pca', 'phase_colors', 'predicted_final_colors', 'predicted_id_E75_colors', 'predicted_id_E85_colors', 'replicates_colors', 'umap', 'umap_density_mark_params'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(adata, color = ['lineage', 'celltype'])

# %%
dict_ct = {'Mesoderm':'Mesoderm',
 'Ectoderm':'Ectoderm',
 'Endoderm':'Endoderm',
           'Pluripotent':'Pluripotent'}

adata.obs['diffx_all'] = (
    adata.obs["lineage"]
    .map(lambda x: dict_ct.get(x, x))
    .astype("category")
)

adata.obs['diffx_all'] = adata.obs['diffx_all'].astype(str)
adata.obs.loc[list(adata[adata.obs['celltype'] == 'mESCs'].obs.index), 'diffx_all'] = 'mESC'
adata.obs.loc[list(adata[adata.obs['celltype_general'] == 'PGCs'].obs.index), 'diffx_all'] = 'x'
adata.obs.loc[list(adata[adata.obs['celltype_general'] == 'Epidermis Progenitors'].obs.index), 'diffx_all'] = 'x'
adata.obs.loc[list(adata[adata.obs['celltype_general'] == 'Epiblast'].obs.index), 'diffx_all'] = 'x'

cols = ['#3787c0', '#fc6832','#df2179', '#58b669','teal','lightgrey']
sc.pl.umap(adata, color = 'diffx_all', palette = cols )

# %% [markdown]
# ## all comparisons

# %%
dict_ct = {'Mesoderm':'x','Ectoderm':'x','Endoderm':'x',
           'Pluripotent':'Pluripotent','x':'x','mESC':'mESC'}
adata.obs['diffx_ESC_p'] = (adata.obs["diffx_all"].map(lambda x: dict_ct.get(x, x)).astype("category"))


dict_ct = {'Mesoderm':'diff','Ectoderm':'diff','Endoderm':'diff',
           'Pluripotent':'Pluripotent','x':'x','mESC':'x'}
adata.obs['diffx_p_diff'] = (adata.obs["diffx_all"].map(lambda x: dict_ct.get(x, x)).astype("category"))

dict_ct = {'Mesoderm':'Mesoderm','Ectoderm':'Ectoderm','Endoderm':'Endoderm',
           'Pluripotent':'Pluripotent','x':'x','mESC':'x'}
adata.obs['diffx_diff_p'] = (adata.obs["diffx_all"].map(lambda x: dict_ct.get(x, x)).astype("category"))

adata.uns['diffx_ESC_p_colors'] = ['#58b669','teal','lightgrey']
adata.uns['diffx_p_diff_colors'] = ['#58b669','#df2179','lightgrey']
adata.uns['diffx_diff_p_colors'] = ['#3787c0', '#fc6832','#df2179', '#58b669','lightgrey']

# %%
sc.pl.umap(adata, color = ['diffx_all','diffx_diff_p','diffx_ESC_p','diffx_p_diff'], ncols = 2)

# %%
adata.obs.head(3)
# Out:
#                                                                      batch  \
# index
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_341  PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_310  PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_302  PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1
#
#                                            day replicates      mark  \
# index
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_341  Gastd5       rep2  H3K27me3
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_310  Gastd5       rep2  H3K27me3
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_302  Gastd5       rep2  H3K27me3
#
#                                             day_rep dataset  hour  \
# index
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_341  Gastd5_rep2     old  120h
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_310  Gastd5_rep2     old  120h
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_302  Gastd5_rep2     old  120h
#
#                                                   celltype  \
# index
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_341         Endothelium
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_310  Neural Progenitors
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_302                NMPs
#
#                                           celltype_general   lineage  ...  \
# index                                                                 ...
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_341          Haemogenic  Mesoderm  ...
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_310  Neural Progenitors  Ectoderm  ...
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_302                NMPs  Ectoderm  ...
#
#                                        phase  enrichment  coverage    QC  \
# index
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_341    G1   78.808261    38.540  good
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_310     S   70.389349    34.978  good
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_302    G1   82.261681    47.160  good
#
#                                         pseudotime  pseudotime2  diffx_all  \
# index
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_341   56.601980    51.219790   Mesoderm
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_310   30.236847    14.116035   Ectoderm
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_302   30.302296    13.390260   Ectoderm
#
#                                        diffx_ESC_p  diffx_p_diff  diffx_diff_p
# index
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_341           x          diff      Mesoderm
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_310           x          diff      Ectoderm
# PZ-MB-TChIC-Gastd5-rep2-H3K27me3-1_302           x          diff      Ectoderm
#
# [3 rows x 27 columns]

# %%
adata.obs['rep'] = adata.obs['batch'].str.rsplit('-', expand=True)[6].replace({'12':'6', '11':'5','10':'4','9':'3','8':'2','7':'1'})

# %%
sc.pl.umap(adata, color = ['rep'])

# %%
sc.settings.verbosity = 2

# %% [markdown]
# # start decoupler
# make pseudobulks, filter, run pydeseq

# %% [markdown]
# ## Identify and isolate groups to compare
# Add back raw counts before pseudobulking - first group cells into pseudobulks, then normalise and log-transform counts again

# %%
groups = 'diffx_ESC_p'
reps = 'rep'

# %%
adata.X = adata.layers['matrix']

# %%
# only keep cells annotated in diffx
adata_f = adata[adata.obs['diffx_ESC_p'] != 'x']

# %%
sc.pl.umap(adata, color = groups)
sc.pl.umap(adata_f, color = groups)
sc.pl.umap(adata_f, color = reps)
# Out:
# /Users/mbloten1/miniconda3/envs/conda_base/lib/python3.10/site-packages/scanpy/plotting/_utils.py:487: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[value_to_plot + "_colors"] = colors_list

# %%
sc.pl.umap(adata_f, color = ['diffx_ESC_p','replicates','mark','dataset','celltype'],ncols=3)

# %% [markdown]
# ## define pseudobulks

# %%
pd.DataFrame(adata_f.obs[[groups]].value_counts())
# Out:
#              count
# diffx_ESC_p
# Pluripotent   6629
# mESC          3896

# %%
plot = adata_f.obs[adata.obs[reps].isin(list(adata_f.obs[reps].value_counts().head(25).index))]
plot[reps] = plot[reps].astype(str)

fig,ax = plt.subplots(figsize = (12,2))
sns.boxplot(data = plot
            ,ax=ax,
           x = reps,
           y = 'n_counts',
           hue = groups)
plt.show()
# Out:
# /var/folders/_k/c0bkq2m10c5f4h7vq_0xfm_40000gn/T/ipykernel_21742/3919780850.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plot = adata_f.obs[adata.obs[reps].isin(list(adata_f.obs[reps].value_counts().head(25).index))]

# %%
# Get pseudo-bulk profile
pdata = dc.get_pseudobulk(
    adata_f,
    groups_col= groups,
    sample_col= reps,
    mode='mean',
    min_cells=10,
    min_counts=0
)

# %%
dc.plot_psbulk_samples(pdata, groupby=[groups, reps],figsize=(12, 4), legend = None)
plt.show()
dc.plot_psbulk_samples(pdata, groupby=['psbulk_counts','psbulk_n_cells'], figsize=(12, 4))
plt.show()
# Out:
# /Users/mbloten1/miniconda3/envs/conda_base/lib/python3.10/site-packages/decoupler/plotting.py:980: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False, title=grp)
# /Users/mbloten1/miniconda3/envs/conda_base/lib/python3.10/site-packages/decoupler/plotting.py:980: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False, title=grp)

# %%
sns.histplot(pdata.obs['psbulk_counts']/pdata.obs['psbulk_n_cells'])
plt.show()

# %% [markdown]
# ## filter pseudobulks

# %%
count_cutoff = 300000
cell_cutoff = 500

# %%
fig,ax = plt.subplots(1,2,figsize = (8,4))
sns.barplot(pdata.obs[groups].value_counts(),ax=ax[0],
            order= adata.obs[groups].cat.categories, palette = adata.uns[str(groups) + '_colors'])
ax[0].set_title('number of pseudobulks')
sns.stripplot(data = pdata.obs,
            x = groups,ax=ax[1],
            y = 'psbulk_n_cells', palette = adata.uns[str(groups) + '_colors'])
ax[1].axhline(cell_cutoff, c='black', linestyle='dashed')
ax[1].set_title('number of cells per pseudobulk')
plt.show()
# Out:
# /var/folders/_k/c0bkq2m10c5f4h7vq_0xfm_40000gn/T/ipykernel_21742/618031605.py:5: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.stripplot(data = pdata.obs,

# %%
fig, ax = plt.subplots(1,2, figsize=(8,4))
ax = ax.flatten()
sns.histplot(data = pdata.obs,
             x = 'psbulk_counts',ax=ax[0], bins = 20, hue = groups, kde = True,
             palette = adata.uns[str(groups) + '_colors'][0:2])
ax[0].axvline(count_cutoff, color = 'black')
sns.histplot(data = pdata.obs,
             x = 'psbulk_n_cells',ax=ax[1], bins = 20, hue = groups, kde = True,
             palette = adata.uns[str(groups) + '_colors'][0:2])
ax[1].axvline(cell_cutoff, color = 'black')
plt.show()

# %%
# Get pseudo-bulk profile
pdata = dc.get_pseudobulk(
    adata_f,
    groups_col=groups,
    sample_col=reps,
    mode='sum',
    min_cells=cell_cutoff,
    min_counts=count_cutoff
)

# %%
dc.plot_psbulk_samples(pdata, groupby=[groups,reps],figsize=(12, 4),legend = None)
plt.show()
# Out:
# /Users/mbloten1/miniconda3/envs/conda_base/lib/python3.10/site-packages/decoupler/plotting.py:980: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False, title=grp)
# /Users/mbloten1/miniconda3/envs/conda_base/lib/python3.10/site-packages/decoupler/plotting.py:980: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False, title=grp)

# %%
fig, ax = plt.subplots(1,2, figsize=(8,4))
ax = ax.flatten()
sns.histplot(data = pdata.obs,
             x = 'psbulk_counts',ax=ax[0], bins = 20, hue = groups, kde = True, 
             palette = adata.uns[str(groups) + '_colors'][0:2])
ax[0].axvline(count_cutoff, color = 'black')
sns.histplot(data = pdata.obs,
             x = 'psbulk_n_cells',ax=ax[1], bins = 20, hue = groups, kde = True,
             palette = adata.uns[str(groups) + '_colors'][0:2])
ax[1].axvline(cell_cutoff, color = 'black')
plt.show()

# %% [markdown]
# ## normalise and log-transform counts

# %%
# Store raw counts in layers
pdata.layers['counts'] = pdata.X.copy()

# Normalize, scale and compute pca
sc.pp.normalize_total(pdata, target_sum=1e4)
sc.pp.log1p(pdata)
sc.pp.scale(pdata, max_value=10)
sc.tl.pca(pdata)

# Return raw counts to X
dc.swap_layer(pdata, 'counts', X_layer_key=None, inplace=True)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# computing PCA
#     with n_comps=11
#     finished (0:00:00)

# %%
sc.pl.pca(pdata, color=[groups], ncols=3, size=300, palette = adata.uns[str(groups) + '_colors'][0:2])
sc.pl.pca_variance_ratio(pdata)

# %%
sc.pl.pca(pdata, color=['QC','psbulk_n_cells', 'psbulk_counts'], ncols=3, size=300)

# %% [markdown]
# ## perform feature (gene) filtering

# %%
count_cutoff = 5
total_cutoff = 250

# %%
dc.plot_filter_by_expr(pdata, group=groups, min_count=count_cutoff, min_total_count=total_cutoff)
plt.show()

# %%
dc.plot_filter_by_expr(pdata, group=reps, min_count=count_cutoff, min_total_count=total_cutoff)
plt.show()

# %%
pdata
# Out:
# AnnData object with n_obs × n_vars = 12 × 27101
#     obs: 'rep', 'diffx_ESC_p', 'lineage', 'QC', 'diffx_all', 'diffx_p_diff', 'diffx_diff_p', 'psbulk_n_cells', 'psbulk_counts'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'gene', 'gene_biotype', 'gene_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'pca', 'diffx_ESC_p_colors', 'QC_colors'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'psbulk_props', 'counts'

# %%
# Obtain genes that pass the thresholds
genes = dc.filter_by_expr(pdata, group=groups, min_count=count_cutoff, min_total_count=total_cutoff)

# Filter by these genes
pdata = pdata[:, genes].copy()
pdata
# Out:
# AnnData object with n_obs × n_vars = 12 × 14624
#     obs: 'rep', 'diffx_ESC_p', 'lineage', 'QC', 'diffx_all', 'diffx_p_diff', 'diffx_diff_p', 'psbulk_n_cells', 'psbulk_counts'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'gene', 'gene_biotype', 'gene_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'pca', 'diffx_ESC_p_colors', 'QC_colors'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'psbulk_props', 'counts'

# %% [markdown]
# ## start DEseq differential analysis

# %%
# Build DESeq2 object
inference = DefaultInference(n_cpus=1)
dds = DeseqDataSet(
    adata=pdata,
    design=groups,
   # ref_level=list(pdata.obs[groups].unique()),
    refit_cooks=True,
    inference=inference,
)

# %%
# Compute LFCs
dds.deseq2()
# Out:
# Fitting size factors...
# ... done in 0.02 seconds.
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting dispersions...
# ... done in 4.64 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.16 seconds.
#
# Fitting MAP dispersions...
# ... done in 4.41 seconds.
#
# Fitting LFCs...
# ... done in 1.57 seconds.
#
# Calculating cook's distance...
# ... done in 0.01 seconds.
#
# Replacing 0 outlier genes.

# %%
list(pdata.obs[groups].unique())
# Out:
# ['Pluripotent', 'mESC']

# %%
# Extract contrast between LINS vs ESC
stat_res = DeseqStats(
    dds,
    contrast=[groups] +  list(pdata.obs[groups].unique()),
    inference=inference,
)

# %%
# Compute Wald test
stat_res.summary()
# Out:
# Running Wald tests...
# Log2 fold change & Wald test p-value: diffx_ESC_p Pluripotent vs mESC
#                   baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# Gene
# 0610005C13Rik    57.172600       -4.320826  0.249784 -17.298226  4.850961e-67
# 0610009B22Rik   173.296061       -0.760960  0.082823  -9.187820  4.008824e-20
# 0610009E02Rik    69.725564       -0.055963  0.133597  -0.418897  6.752914e-01
# 0610009L18Rik    26.534472       -0.066941  0.228923  -0.292417  7.699681e-01
# 0610012G03Rik   184.195273       -0.630959  0.087599  -7.202781  5.899661e-13
# ...                    ...             ...       ...        ...           ...
# Zyg11b         1217.405456        0.750208  0.040818  18.379485  1.917822e-75
# Zyx             635.438138        3.716699  0.087113  42.665127  0.000000e+00
# Zzef1           726.616174        0.179783  0.046105   3.899394  9.643380e-05
# Zzz3           2893.275186       -0.196845  0.034104  -5.771875  7.839448e-09
# a               216.629150       -0.407212  0.074684  -5.452434  4.968511e-08
#
#                        padj
# Gene
# 0610005C13Rik  2.522776e-66
# 0610009B22Rik  9.774099e-20
# 0610009E02Rik  6.989992e-01
# 0610009L18Rik  7.879103e-01
# 0610012G03Rik  1.164013e-12
# ...                     ...
# Zyg11b         1.090869e-74
# Zyx            0.000000e+00
# Zzef1          1.354315e-04
# Zzz3           1.325212e-08
# a              8.152082e-08
#
# [14624 rows x 6 columns]
# ... done in 0.61 seconds.

# %%
# Extract results
results_df = stat_res.results_df

results_df.head(2)
# Out:
#                  baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# Gene
# 0610005C13Rik   57.172600       -4.320826  0.249784 -17.298226  4.850961e-67
# 0610009B22Rik  173.296061       -0.760960  0.082823  -9.187820  4.008824e-20
#
#                        padj
# Gene
# 0610005C13Rik  2.522776e-66
# 0610009B22Rik  9.774099e-20

# %%
dc.plot_volcano_df(
    results_df,
    x='log2FoldChange',
    y='padj',
    top=5,
    figsize=(4,4)
)
plt.show()
# Out:
# /Users/mbloten1/miniconda3/envs/conda_base/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ## Identify diff expressed genes

# %%
results_df['p_log10'] = -np.log10(results_df['padj'])
#results_df = results_df[np.isfinite(results_df['p_log10'])]


up = results_df[(results_df['padj'] < 0.05) & (results_df['log2FoldChange'] > 2)].sort_values(by = 'log2FoldChange',ascending=True)

down = results_df[(results_df['padj'] < 0.05) & (results_df['log2FoldChange'] < -2)].sort_values(by = 'log2FoldChange',ascending=True)
# Out:
# /Users/mbloten1/miniconda3/envs/conda_base/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
results_df.head(2)
# Out:
#                  baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# Gene
# 0610005C13Rik   57.172600       -4.320826  0.249784 -17.298226  4.850961e-67
# 0610009B22Rik  173.296061       -0.760960  0.082823  -9.187820  4.008824e-20
#
#                        padj    p_log10
# Gene
# 0610005C13Rik  2.522776e-66  65.598121
# 0610009B22Rik  9.774099e-20  19.009923

# %%
results_df.to_csv('dfs/20250310_diff_genes_ESCvsP.csv')

# %%
pdata
# Out:
# AnnData object with n_obs × n_vars = 12 × 14624
#     obs: 'rep', 'diffx_ESC_p', 'lineage', 'QC', 'diffx_all', 'diffx_p_diff', 'diffx_diff_p', 'psbulk_n_cells', 'psbulk_counts'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'gene', 'gene_biotype', 'gene_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'pca', 'diffx_ESC_p_colors', 'QC_colors', 'trend_coeffs', 'disp_function_type', '_squared_logres', 'prior_disp_var'
#     obsm: 'X_pca', 'design_matrix', 'size_factors', '_mu_LFC', '_hat_diagonals', 'replaceable'
#     varm: 'PCs', '_normed_means', 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'refitted', '_pvalue_cooks_outlier'
#     layers: 'psbulk_props', 'counts', 'normed_counts', '_mu_hat', 'cooks'

# %% [markdown]
# # do standard scanpy diff gene analysis

# %%
sc.tl.rank_genes_groups(adata_f, groupby = groups,method='wilcoxon')
# Out:
# ranking genes
#     finished (0:00:11)

# %%
sc.pl.rank_genes_groups(adata_f, n_genes=10, sharey=False)

# %%
sc.pl.rank_genes_groups_dotplot(
    adata_f, groupby=groups, standard_scale="var", n_genes=5
)
plt.show()
# Out:
# WARNING: Dendrogram not added. Dendrogram is added only when the number of categories to plot > 2

# %%
diff_exp = sc.get.rank_genes_groups_df(adata_f, group=adata_f.obs[groups].unique()[0])
diff_exp.index = diff_exp['names']
diff_exp = diff_exp.rename(columns = {'logfoldchanges':'log2FoldChange', 'pvals_adj': 'padj','scores':'stat'})
diff_exp['p_log10'] = -np.log10(diff_exp['padj'])
diff_exp = diff_exp[np.isfinite(diff_exp['p_log10'])]


scanpy_up = diff_exp[(diff_exp['log2FoldChange'] > 2) & (diff_exp['padj'] < 0.05)]
scanpy_down = diff_exp[(diff_exp['log2FoldChange'] < -2) & (diff_exp['padj'] < 0.05)]
# Out:
# /Users/mbloten1/miniconda3/envs/conda_base/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
scanpy_up.shape
# Out:
# (817, 6)

# %%
scanpy_down.shape
# Out:
# (528, 6)

# %% [markdown]
# # check intersect between deseq2 and scanpy

# %%
from venny4py.venny4py import *

#dict of sets
sets = {
    'A': set(list(up.index)),
    'B': set(list(scanpy_up['names'])),
    'C': set(list(down.index)),
    'D': set(list(scanpy_down['names']))}
    
venny4py(sets=sets, )#colors = list(lin_colors.values()),)

#plt.savefig('figs/venn4.png',bbox_inches='tight')
plt.show()

# %%
sc.set_figure_params(dpi = 80)

sns.set_style("white")
sns.set_context("talk")
sns.set_style("ticks")

# %%
from matplotlib_venn import venn2, venn2_circles

A = up.index
B = scanpy_up['names']

fig,ax = plt.subplots(figsize = (3,3))
venn2([set(A),set(B)],ax=ax, set_colors = [adata.uns[str(groups) + '_colors'][0] , 'grey'],set_labels = ['deseq2','scanpy'],
      alpha = 0.7)
c = venn2_circles([set(A),set(B)],color = 'black',linewidth = 1,ax=ax, 
      alpha = 0.6)

#plt.savefig('figs/venn3_neg.png',bbox_inches='tight')
plt.show()

# %%
from matplotlib_venn import venn2, venn2_circles

A = down.index
B = scanpy_down['names']

fig,ax = plt.subplots(figsize = (3,3))
venn2([set(A),set(B)],ax=ax, set_colors = [adata.uns[str(groups) + '_colors'][1] , 'grey'], set_labels = ['deseq2','scanpy'],
      alpha = 0.7)
c = venn2_circles([set(A),set(B)],color = 'black',linewidth = 1,ax=ax, 
      alpha = 0.6)
#plt.savefig('figs/venn3_neg.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# # all plots for diff expressed genes

# %%
def makeVolcano(df, df_up, df_down, lfc = 'log2FoldChange'):
    fig,ax = plt.subplots(figsize = (4,4))
    
    sns.scatterplot(data = df,
                   x = lfc,s=12,edgecolor = None,
                   y = 'p_log10',alpha = 0.4,
                   c = 'grey')
    
    sns.scatterplot(data = df_up,
                   x = lfc,s=12,edgecolor = None,
                   y = 'p_log10',
                   c = adata.uns[str(groups) + '_colors'][0] )
    
    sns.scatterplot(data = df_down,
                   x = lfc,s=12,edgecolor = None,
                   y = 'p_log10',
                   c = adata.uns[str(groups) + '_colors'][1] )
    ax.legend([],frameon=False)
    ax.set_ylabel('log10 [p-value]')
    ax.set_xlabel('log2 FC')
    
    
    #plt.savefig('figs/volcanoes_diffexpressed.png', bbox_inches='tight')
    plt.show()

# %%
makeVolcano(results_df,up,down)

# %%
makeVolcano(diff_exp,scanpy_up,scanpy_down)

# %%
allgenes = list(results_df.index.unique())
def plotGO(genelist, reflist, n = 10, save = None, source = 'GO:BP'):
    plotcl = sc.queries.enrich({'cluster':genelist,
                   'all':reflist}, org="mmusculus")
    cluster = 'cluster'
    plot1 = plotcl[plotcl['query'] == cluster][plotcl[plotcl['query'] == cluster]['source'] == source].sort_values(by='p_value')[['name','p_value']][0:n]
    plot1['-log (p-value)'] = np.log10(plot1['p_value'])*-1
    sns.set_style('ticks')
    sns.set_context('talk')
    fig,ax = plt.subplots(figsize = (6,3))
    ax = sns.barplot(y=plot1['name'],x=plot1['-log (p-value)'], ax=ax,color = 'grey')
    ax.set_ylabel('')
    if save != None:
        plt.savefig(save , bbox_inches='tight')
    #sns.despine()
    plt.show()

# %%
len(list(up.index))
# Out:
# 819

# %%
len(list(down.index))
# Out:
# 826

# %%
plotGO(list(up.index),allgenes, n = 5)
plotGO(list(scanpy_up['names']),allgenes, n = 5)

# %%
plotGO(list(down.index),allgenes, n = 5)
plotGO(list(scanpy_down['names']),allgenes, n = 5)

# %% [markdown]
# ## Gene regulatory network analysis

# %%
# Retrieve CollecTRI gene regulatory network
collectri = dc.get_collectri(organism='mouse', split_complexes=False,)

collectri.head(2)
# Out:
# /Users/mbloten1/miniconda3/envs/conda_base/lib/python3.10/site-packages/liana/resource/_orthology.py:199: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   source target  weight
# 0    AP1  Aanat       1
# 1    AP1  Abca1      -1

# %%
def plotTFs(df, save = None, cmap = 'coolwarm'):
    mat = df[['stat']].T.rename(index={'stat': 'diff'})
    tf_acts, tf_pvals = dc.run_ulm(mat=mat, net=collectri)
    dc.plot_barplot(
    acts=tf_acts,
    contrast='diff',
    top=25,cmap = cmap,
    vertical=True,
    figsize=(3, 6)
    )
    if save != None:
        plt.savefig(save, bbox_inches = 'tight')
    plt.show()

# %%
plotTFs(results_df, cmap =sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))
plotTFs(diff_exp, cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))

# %%
plotTFs(up, cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))
plotTFs(scanpy_up, cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))

# %%
plotTFs(down, cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))
plotTFs(scanpy_down, cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))

# %% [markdown]
# ### check overlaps

# %%
overlap_full = set(results_df.index) & set(diff_exp.index)
overlap_up = set(up.index) & set(scanpy_up.index)
overlap_down = set(down.index) & set(scanpy_down.index)

# %%
plotTFs(results_df.loc[list(overlap_full)], cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))
plotTFs(diff_exp.loc[list(overlap_full)], cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))

# %%
plotTFs(up.loc[list(overlap_up)], cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))
plotTFs(scanpy_up.loc[list(overlap_up)], cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))

# %%
plotTFs(down.loc[list(overlap_down)], cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))
plotTFs(scanpy_down.loc[list(overlap_down)], cmap = sns.blend_palette(["teal",'lightgrey', '#58b669'], as_cmap=True))

# %% [markdown]
# ## conclusions: deseq and scanpy do largely agree on the genes that are differentially expressed, but the scores are wildly different. Therefore, the venn diagram shows considerable overlap between the gene sets and the (geneset-based) GO analysis is also comparable, but the (score-based) TF activity inference shows different results.
